# %%
# !pip install pycorenlp
# !pip install pyneuroner[gpu]
# !python -m spacy download es

# %%
# -*- coding: utf-8 -*-
#source code available at https://github.com/juand-r/entity-recognition-datasets/tree/master/data/i2b2_2014
#another source : https://github.com/Franck-Dernoncourt/NeuroNER
import codecs
import glob
import json
import os

from pycorenlp import StanfordCoreNLP
import spacy

from neuroner import utils_nlp


def get_start_and_end_offset_of_token_from_spacy(token):
    start = token.idx
    end = start + len(token)
    return start, end

def get_sentences_and_tokens_from_spacy(text, spacy_nlp):
    document = spacy_nlp(text)
    # sentences
    sentences = []
    for span in document.sents:
        sentence = [document[i] for i in range(span.start, span.end)]
        sentence_tokens = []
        for token in sentence:
            token_dict = {}
            token_dict['start'], token_dict['end'] = get_start_and_end_offset_of_token_from_spacy(token)
            token_dict['text'] = text[token_dict['start']:token_dict['end']]
            if token_dict['text'].strip() in ['\n', '\t', ' ', '']:
                continue
            # Make sure that the token text does not contain any space
            if len(token_dict['text'].split(' ')) != 1:
                print("WARNING: the text of the token contains space character, replaced with hyphen\n\t{0}\n\t{1}".format(token_dict['text'], 
                                                                                                                           token_dict['text'].replace(' ', '-')))
                token_dict['text'] = token_dict['text'].replace(' ', '-')
            sentence_tokens.append(token_dict)
        sentences.append(sentence_tokens)
    return sentences

def get_stanford_annotations(text, core_nlp, port=9000, annotators='tokenize,ssplit,pos,lemma'):
    output = core_nlp.annotate(text, properties={
        "timeout": "10000",
        "ssplit.newlineIsSentenceBreak": "two",
        'annotators': annotators,
        'outputFormat': 'json'
    })
    if type(output) is str:
        output = json.loads(output, strict=False)
    return output

def get_sentences_and_tokens_from_stanford(text, core_nlp):
    stanford_output = get_stanford_annotations(text, core_nlp)
    sentences = []
    for sentence in stanford_output['sentences']:
        tokens = []
        for token in sentence['tokens']:
            token['start'] = int(token['characterOffsetBegin'])
            token['end'] = int(token['characterOffsetEnd'])
            token['text'] = text[token['start']:token['end']]
            if token['text'].strip() in ['\n', '\t', ' ', '']:
                continue
            # Make sure that the token text does not contain any space
            if len(token['text'].split(' ')) != 1:
                print("WARNING: the text of the token contains space character, replaced with hyphen\n\t{0}\n\t{1}".format(token['text'], 
                                                                                                                           token['text'].replace(' ', '-')))
                token['text'] = token['text'].replace(' ', '-')
            tokens.append(token)
        sentences.append(tokens)
    return sentences

def get_entities_from_brat(text_filepath, annotation_filepath, verbose=False):
    # load text
    with codecs.open(text_filepath, 'r', 'UTF-8') as f:
        text =f.read()
    if verbose: print("\ntext:\n{0}\n".format(text))

    # parse annotation file
    entities = []
    with codecs.open(annotation_filepath, 'r', 'UTF-8') as f:
        for line in f.read().splitlines():
            anno = line.split()
            id_anno = anno[0]
            # parse entity
            if id_anno[0] == 'T':
                entity = {}
                entity['id'] = id_anno
                entity['type'] = anno[1]
                entity['start'] = int(anno[2])
                entity['end'] = int(anno[3])
                entity['text'] = ' '.join(anno[4:])
                if verbose:
                    print("entity: {0}".format(entity))
                # Check compatibility between brat text and anootation
                if utils_nlp.replace_unicode_whitespaces_with_ascii_whitespace(text[entity['start']:entity['end']]) != \
                    utils_nlp.replace_unicode_whitespaces_with_ascii_whitespace(entity['text']):
                    print("Warning: brat text and annotation do not match.")
                    print("\ttext: {0}".format(text[entity['start']:entity['end']]))
                    print("\tanno: {0}".format(entity['text']))
                # add to entitys data
                entities.append(entity)
    if verbose: print("\n\n")
    
    return text, entities

def check_brat_annotation_and_text_compatibility(brat_folder):
    '''
    Check if brat annotation and text files are compatible.
    '''
    dataset_type =  os.path.basename(brat_folder)
    print("Checking the validity of BRAT-formatted {0} set... ".format(dataset_type), end='')
    text_filepaths = sorted(glob.glob(os.path.join(brat_folder, '*.txt')))
    for text_filepath in text_filepaths:
        base_filename = os.path.splitext(os.path.basename(text_filepath))[0]
        annotation_filepath = os.path.join(os.path.dirname(text_filepath), base_filename + '.ann')
        # check if annotation file exists
        if not os.path.exists(annotation_filepath):
            raise IOError("Annotation file does not exist: {0}".format(annotation_filepath))
        text, entities = get_entities_from_brat(text_filepath, annotation_filepath)
    print("Done.")

def brat_to_conll(input_folder, output_filepath, tokenizer, language):
    '''
    Assumes '.txt' and '.ann' files are in the input_folder.
    Checks for the compatibility between .txt and .ann at the same time.
    '''
    if tokenizer == 'spacy':
        spacy_nlp = spacy.load(language)
    elif tokenizer == 'stanford':
        core_nlp = StanfordCoreNLP('http://localhost:{0}'.format(9000))
    else:
        raise ValueError("tokenizer should be either 'spacy' or 'stanford'.")
    verbose = False
    dataset_type =  os.path.basename(input_folder)
    print("Formatting {0} set from BRAT to CONLL... ".format(dataset_type), end='')
    text_filepaths = sorted(glob.glob(os.path.join(input_folder, '*.txt')))
    output_file = codecs.open(output_filepath, 'w', 'utf-8')
    for text_filepath in text_filepaths:
        base_filename = os.path.splitext(os.path.basename(text_filepath))[0]
        annotation_filepath = os.path.join(os.path.dirname(text_filepath), base_filename + '.ann')
        # create annotation file if it does not exist
        if not os.path.exists(annotation_filepath):
            codecs.open(annotation_filepath, 'w', 'UTF-8').close()

        text, entities = get_entities_from_brat(text_filepath, annotation_filepath)
        entities = sorted(entities, key=lambda entity:entity["start"])
        
        if tokenizer == 'spacy':
            sentences = get_sentences_and_tokens_from_spacy(text, spacy_nlp)
        elif tokenizer == 'stanford':
            sentences = get_sentences_and_tokens_from_stanford(text, core_nlp)
        
        for sentence in sentences:
            inside = False
            previous_token_label = 'O'
            for token in sentence:
                token['label'] = 'O'
                for entity in entities:
                    if entity['start'] <= token['start'] < entity['end'] or \
                       entity['start'] < token['end'] <= entity['end'] or \
                       token['start'] < entity['start'] < entity['end'] < token['end']:

                        token['label'] = entity['type'].replace('-', '_') # Because the ANN doesn't support tag with '-' in it

                        break
                    elif token['end'] < entity['start']:
                        break
                        
                if len(entities) == 0:
                    entity={'end':0}
                if token['label'] == 'O':
                    gold_label = 'O'
                    inside = False
                elif inside and token['label'] == previous_token_label:
                    gold_label = 'I-{0}'.format(token['label'])
                else:
                    inside = True
                    gold_label = 'B-{0}'.format(token['label'])
                if token['end'] == entity['end']:
                    inside = False
                previous_token_label = token['label']
                if verbose: print('{0} {1} {2} {3} {4}\n'.format(token['text'], base_filename, token['start'], token['end'], gold_label))
                output_file.write('{0} {1} {2} {3} {4}\n'.format(token['text'], base_filename, token['start'], token['end'], gold_label))
            if verbose: print('\n')
            output_file.write('\n')

    output_file.close()
    print('Done.')
    if tokenizer == 'spacy':
        del spacy_nlp
    elif tokenizer == 'stanford':
        del core_nlp

# %%
brat_to_conll('../input/meddoprofner-task/experiments/experiments/test', './test.txt', 'spacy', 'es')
brat_to_conll('../input/meddoprofner-task/meddoprof-train-set/task1', './train.txt', 'spacy', 'es')
# Out:
# Formatting test set from BRAT to CONLL... Done.
# Formatting task1 set from BRAT to CONLL... Done.

# %%
import pandas as pd
test=pd.read_csv('./test.txt',sep=' ',names=['words','fileId','start','end','label'],quoting=3, error_bad_lines=False)
test.head()
# Out:
#        words                     fileId  start  end label
# 0     Nombre  S0034-98872006000200012-1      0    6     O
# 1          :  S0034-98872006000200012-1      6    7     O
# 2    Gabriel  S0034-98872006000200012-1      8   15     O
# 3          .  S0034-98872006000200012-1     16   17     O
# 4  Apellidos  S0034-98872006000200012-1     18   27     O

# %%
import pandas as pd
train=pd.read_csv('./train.txt',sep=' ',names=['words','fileId','start','end','label'],quoting=3, error_bad_lines=False)
train.head()
# Out:
#        words       fileId  start  end label
# 0         Un  32247016_ES      0    2     O
# 1   paciente  32247016_ES      3   11     O
# 2         de  32247016_ES     12   14     O
# 3       unos  32247016_ES     15   19     O
# 4  cincuenta  32247016_ES     20   29     O

# %%
set(train.label)
# Out:
# {'B-ACTIVIDAD',
#  'B-PROFESION',
#  'B-SITUACION_LABORAL',
#  'I-ACTIVIDAD',
#  'I-PROFESION',
#  'I-SITUACION_LABORAL',
#  'O'}

# %%
# !pip install -q flair
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyldavis 3.3.1 requires numpy>=1.20.0, but you have numpy 1.19.5 which is incompatible.
# pyldavis 3.3.1 requires pandas>=1.2.0, but you have pandas 1.1.5 which is incompatible.

# %%
from flair.data import Corpus
from flair.datasets import ColumnCorpus

# %%
columns = {0: 'words', 4: 'label'}
corpus: Corpus = ColumnCorpus('./', columns,
                              train_file='./train.txt',
                              test_file='./test.txt',
                              dev_file='./test.txt')
# Out:
# 2021-06-06 03:30:03,448 Reading data from .
# 2021-06-06 03:30:03,449 Train: train.txt
# 2021-06-06 03:30:03,450 Dev: test.txt
# 2021-06-06 03:30:03,451 Test: test.txt

# %%
import pandas as pd
data = [[len(corpus.train), len(corpus.test), len(corpus.dev)]]
# Prints out the dataset sizes of train test and development in a table.
pd.DataFrame(data, columns=["Train", "Test", "Development"])
# Out:
#    Train   Test  Development
# 0  49640  10002        10002

# %%
from flair.embeddings import TransformerWordEmbeddings

embeddings = TransformerWordEmbeddings(
    model='dccuchile/bert-base-spanish-wwm-cased',
    layers="-1",
    subtoken_pooling="first",
    fine_tune=True,
    use_context=True,
)
# Out:
# Downloading:   0%|          | 0.00/648 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/480k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/134 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/364 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertModel were not initialized from the model checkpoint at dccuchile/bert-base-spanish-wwm-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# 5. initialize bare-bones sequence tagger (no CRF, no RNN, no reprojection)
from flair.models import SequenceTagger
# 2. what tag do we want to predict?
tag_type = 'label'

# 3. make the tag dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)

tagger = SequenceTagger(
    hidden_size=256,
    embeddings=embeddings,
    tag_dictionary=tag_dictionary,
    tag_type='label',
    use_crf=False,
    use_rnn=False,
    reproject_embeddings=False,
)

# %%
# 6. initialize trainer with AdamW optimizer
from flair.trainers import ModelTrainer
import torch

trainer = ModelTrainer(tagger, corpus, optimizer=torch.optim.AdamW)

# %%
# 7. run training with XLM parameters (20 epochs, small LR)
from torch.optim.lr_scheduler import OneCycleLR

trainer.train('resources/taggers/ner-spanish-large',
              learning_rate=5.0e-6,
              mini_batch_size=4,
              mini_batch_chunk_size=1,
              max_epochs=10,
              scheduler=OneCycleLR,
              embeddings_storage_mode='gpu',
              weight_decay=0.,
              )
# Out:
# 2021-06-06 03:31:06,262 ----------------------------------------------------------------------------------------------------
# 2021-06-06 03:31:06,265 Model: "SequenceTagger(
#   (embeddings): TransformerWordEmbeddings(
#     (model): BertModel(
#       (embeddings): BertEmbeddings(
#         (word_embeddings): Embedding(31002, 768, padding_idx=1)
#         (position_embeddings): Embedding(512, 768)
#         (token_type_embeddings): Embedding(2, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): BertEncoder(
#         (layer): ModuleList(
#           (0): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (1): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (2): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (3): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (4): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (5): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (6): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (7): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (8): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (9): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (10): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (11): BertLayer(
#             (attention): BertAttention(
#               (self): BertSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (output): BertSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#             (intermediate): BertIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (output): BertOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (pooler): BertPooler(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (activation): Tanh()
#       )
#     )
#   )
#   (word_dropout): WordDropout(p=0.05)
#   (locked_dropout): LockedDropout(p=0.5)
#   (linear): Linear(in_features=768, out_features=10, bias=True)
#   (beta): 1.0
#   (weights): None
#   (weight_tensor) None
# )"
# 2021-06-06 03:31:06,267 ----------------------------------------------------------------------------------------------------
# 2021-06-06 03:31:06,268 Corpus: "Corpus: 49640 train + 10002 dev + 10002 test sentences"
# 2021-06-06 03:31:06,269 ----------------------------------------------------------------------------------------------------
# 2021-06-06 03:31:06,270 Parameters:
# 2021-06-06 03:31:06,271  - learning_rate: "5e-06"
# 2021-06-06 03:31:06,272  - mini_batch_size: "4"
# 2021-06-06 03:31:06,273  - patience: "3"
# 2021-06-06 03:31:06,274  - anneal_factor: "0.5"
# 2021-06-06 03:31:06,275  - max_epochs: "10"
# 2021-06-06 03:31:06,276  - shuffle: "True"
# 2021-06-06 03:31:06,277  - train_with_dev: "False"
# 2021-06-06 03:31:06,278  - batch_growth_annealing: "False"
# 2021-06-06 03:31:06,279 ----------------------------------------------------------------------------------------------------
# 2021-06-06 03:31:06,279 Model training base path: "resources/taggers/ner-spanish-large"
# 2021-06-06 03:31:06,280 ----------------------------------------------------------------------------------------------------
# 2021-06-06 03:31:06,281 Device: cuda:0
# 2021-06-06 03:31:06,282 ----------------------------------------------------------------------------------------------------
# 2021-06-06 03:31:06,282 Embeddings storage mode: gpu
# 2021-06-06 03:31:06,289 ----------------------------------------------------------------------------------------------------
# 2021-06-06 03:35:40,713 epoch 1 - iter 1241/12410 - loss 0.19143667 - samples/sec: 18.09 - lr: 0.000005
# Token indices sequence length is longer than the specified maximum sequence length for this model (660 > 512). Running this sequence through the model will result in indexing errors
# 2021-06-06 03:40:22,020 epoch 1 - iter 2482/12410 - loss 0.16222971 - samples/sec: 17.65 - lr: 0.000005
# 2021-06-06 03:45:03,125 epoch 1 - iter 3723/12410 - loss 0.14997034 - samples/sec: 17.66 - lr: 0.000005
# 2021-06-06 11:45:57,719 epoch 10 - iter 6205/12410 - loss 0.09550569 - samples/sec: 17.39 - lr: 0.000000
# 2021-06-06 11:50:42,888 epoch 10 - iter 7446/12410 - loss 0.09550795 - samples/sec: 17.41 - lr: 0.000000
# 2021-06-06 11:55:26,839 epoch 10 - iter 8687/12410 - loss 0.09503176 - samples/sec: 17.48 - lr: 0.000000
# 2021-06-06 12:00:12,341 epoch 10 - iter 9928/12410 - loss 0.09496917 - samples/sec: 17.39 - lr: 0.000000
# 2021-06-06 12:04:52,014 epoch 10 - iter 11169/12410 - loss 0.09490567 - samples/sec: 17.75 - lr: 0.000000
# 2021-06-06 12:09:33,828 epoch 10 - iter 12410/12410 - loss 0.09448508 - samples/sec: 17.62 - lr: 0.000000
# 2021-06-06 12:09:33,832 ----------------------------------------------------------------------------------------------------
# 2021-06-06 12:09:33,833 EPOCH 10 done: loss 0.0945 - lr 0.0000000
# 2021-06-06 12:14:35,427 DEV : loss 9.802718705032021e-05 - score 0.9915
# 2021-06-06 12:14:35,499 BAD EPOCHS (no improvement): 4
# 2021-06-06 12:14:36,328 ----------------------------------------------------------------------------------------------------
# 2021-06-06 12:14:36,329 Testing using best model ...
# 2021-06-06 12:19:36,188 0.9872	0.9957	0.9915
# 2021-06-06 12:19:36,189
# Results:
# - F1-score (micro) 0.9915
# - F1-score (macro) 0.9590
#
# By class:
# ACTIVIDAD  tp: 5 - fp: 0 - fn: 1 - precision: 1.0000 - recall: 0.8333 - f1-score: 0.9091
# PROFESION  tp: 364 - fp: 1 - fn: 0 - precision: 0.9973 - recall: 1.0000 - f1-score: 0.9986
# SITUACION_LABORAL tp: 95 - fp: 5 - fn: 1 - precision: 0.9500 - recall: 0.9896 - f1-score: 0.9694
# 2021-06-06 12:19:36,190 ----------------------------------------------------------------------------------------------------
# {'test_score': 0.9914529914529914,
#  'dev_score_history': [0.8721804511278195,
#   0.9298429319371727,
#   0.9603429796355841,
#   0.9661733615221988,
#   0.985042735042735,
#   0.9914529914529914,
#   0.9925293489861259,
#   0.9903948772678762,
#   0.9914529914529914,
#   0.9914529914529914],
#  'train_loss_history': [0.13699906963480882,
#   0.11770114456034944,
#   0.10816561263953835,
#   0.10411377371401635,
#   0.09948162731419896,
#   0.09748751203627926,
#   0.09346435220860712,
#   0.09360180739185398,
#   0.09264584391795248,
#   0.0944850795910929],
#  'dev_loss_history': [0.0042916531674563885,
#   0.0014818062772974372,
#   0.0008463345584459603,
#   0.0006835437961854041,
#   0.00042431947076693177,
#   0.00021610480325762182,
#   0.00020059198141098022,
#   0.00012177122698631138,
#   0.00010632267367327586,
#   9.802718705032021e-05]}

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

input_sentence = 'Un paciente de unos cincuenta años sin antecedentes personales acudió a su médico de cabecera en la zona de Marsella el 6 de marzo de 2020 , reportando fiebre , cefalea y tos con una evolución desde el 29 de febrero .' 
tagger: SequenceTagger = SequenceTagger.load("./resources/taggers/ner-spanish-large/final-model.pt")
sentence: Sentence = Sentence(input_sentence)
tagger.predict(sentence)
print(sentence.to_tagged_string())
# Out:
# 2021-06-06 12:19:36,203 loading file ./resources/taggers/ner-spanish-large/final-model.pt
# Un paciente de unos cincuenta años sin antecedentes personales acudió a su médico <B-PROFESION> de <I-PROFESION> cabecera <I-PROFESION> en la zona de Marsella el 6 de marzo de 2020 , reportando fiebre , cefalea y tos con una evolución desde el 29 de febrero .

# %%
#sentence.get_spans()

# %%
# !zip -r ./flair_bert_meddoprof.zip ./resources/taggers/ner-spanish-large
# Out:
#   adding: resources/taggers/ner-spanish-large/ (stored 0%)
#   adding: resources/taggers/ner-spanish-large/training.log (deflated 88%)
#   adding: resources/taggers/ner-spanish-large/dev.tsv (deflated 77%)
#   adding: resources/taggers/ner-spanish-large/loss.tsv (deflated 53%)
#   adding: resources/taggers/ner-spanish-large/test.tsv (deflated 77%)
#   adding: resources/taggers/ner-spanish-large/final-model.pt (deflated 7%)
#   adding: resources/taggers/ner-spanish-large/weights.txt (stored 0%)

# %%
#tagger: SequenceTagger = SequenceTagger.load("./resources/taggers/ner-spanish-large/final-model.pt")

def ftagger(txt):
    sentence: Sentence = Sentence(txt)
    tagger.predict(sentence)
    return sentence.get_spans()#sentence.to_tagged_string()

# %%
#!rm -r ./out
# !mkdir ./out
def format(path):
    file=open(path).read()
    out=ftagger(file)
    fname=str(path).split('/')[-1][:-4]
    ann=open("./out/"+fname+".ann", "w")
    i=1
    for ntt in out:
        ntt=ntt.to_dict()
        text=ntt['text']
        start=ntt['start_pos']
        end=ntt['end_pos']
        tag=str(ntt['labels']).split(' ')[0][1:]
        ann.write('T'+str(i)+'\t'+tag+' '+str(start)+' '+str(end)+'\t'+text+'\n')
        i=i+1

# %%
#!rm -r ./resources

# %%
import os
from pathlib import Path
path=Path('../input/meddoprofner-task/meddoprof_test_txt/meddoprof_test_txt')

# %%
for user in os.listdir(path):
            if str(user)[-1]=='n' : 
                continue
            print("\t\t Working on text: ", user )
            format(os.path.join(path, user))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (740 > 512). Running this sequence through the model will result in indexing errors
# 		 Working on text:  casos_clinicos_profesiones181.txt
# 		 Working on text:  caso_clinico_psiquiatria438.txt
# 		 Working on text:  casos_clinicos_profesiones113.txt
# 		 Working on text:  cc_onco884.txt
# 		 Working on text:  casos_clinicos_profesiones134.txt
# 		 Working on text:  caso_clinico_dermatologia456.txt
# 		 Working on text:  casos_clinicos_profesiones222.txt
# 		 Working on text:  cc_onco1574.txt
# 		 Working on text:  caso_clinico_psiquiatria471.txt
# 		 Working on text:  casos_clinicos_profesiones145.txt
# 		 Working on text:  casos_clinicos_profesiones141.txt
# 		 Working on text:  caso_clinico_medicina_interna407.txt
# 		 Working on text:  casos_clinicos_profesiones167.txt
# 		 Working on text:  caso_clinico_endocrinologia47.txt
# 		 Working on text:  caso_clinico_psiquiatria22.txt
# 		 Working on text:  casos_clinicos_profesiones138.txt
# 		 Working on text:  casos_clinicos_profesiones232.txt
# 		 Working on text:  caso_clinico_psiquiatria69.txt
# 		 Working on text:  caso_clinico_psiquiatria360.txt
# 		 Working on text:  casos_clinicos_profesiones166.txt
# 		 Working on text:  casos_clinicos_profesiones196.txt
# 		 Working on text:  casos_clinicos_profesiones71.txt
# 		 Working on text:  caso_clinico_psiquiatria366.txt
# 		 Working on text:  cc_onco611.txt
# 		 Working on text:  caso_clinico_oftalmologia188.txt
# 		 Working on text:  casos_clinicos_profesiones106.txt
# 		 Working on text:  cc_onco627.txt
# 		 Working on text:  casos_clinicos_profesiones178.txt
# 		 Working on text:  caso_clinico_neurologia347.txt
# 		 Working on text:  caso_clinico_urologia58.txt
# 		 Working on text:  casos_clinicos_profesiones168.txt
# 		 Working on text:  cc_reuma35.txt
# 		 Working on text:  casos_clinicos_profesiones192.txt
# 		 Working on text:  caso_clinico_psiquiatria229.txt
# 		 Working on text:  cc_reuma14.txt
# 		 Working on text:  cc_reuma3.txt
# 		 Working on text:  caso_clinico_radiologia920.txt
# 		 Working on text:  caso_clinico_medicina_interna1700.txt
# 		 Working on text:  caso_clinico_dermatologia469.txt
# 		 Working on text:  casos_clinicos_profesiones195.txt
# 		 Working on text:  casos_clinicos_profesiones125.txt
# 		 Working on text:  casos_clinicos_profesiones210.txt
# 		 Working on text:  casos_clinicos_profesiones159.txt
# 		 Working on text:  caso_clinico_medicina_interna644.txt
# 		 Working on text:  casos_clinicos_profesiones147.txt
# 		 Working on text:  caso_clinico_atencion_primaria92.txt
# 		 Working on text:  casos_clinicos_profesiones187.txt
# 		 Working on text:  caso_clinico_neurologia115.txt
# 		 Working on text:  caso_clinico_dermatologia160.txt
# 		 Working on text:  casos_clinicos_profesiones173.txt
# 		 Working on text:  casos_clinicos_profesiones129.txt
# 		 Working on text:  caso_clinico_psiquiatria518.txt
# 		 Working on text:  casos_clinicos_profesiones117.txt
# 		 Working on text:  caso_clinico_dermatologia123.txt
# 		 Working on text:  cc_onco1033.txt
# 		 Working on text:  casos_clinicos_profesiones112.txt
# 		 Working on text:  caso_clinico_medicina_interna996.txt
# 		 Working on text:  casos_clinicos_profesiones116.txt
# 		 Working on text:  S0034-98872006000200011-1.txt
# 		 Working on text:  caso_clinico_dermatologia390.txt
# 		 Working on text:  casos_clinicos_profesiones7.txt
# 		 Working on text:  casos_clinicos_profesiones115.txt
# 		 Working on text:  caso_clinico_neurologia195.txt
# 		 Working on text:  casos_clinicos_profesiones158.txt
# 		 Working on text:  caso_clinico_medicina_interna240.txt
# 		 Working on text:  caso_clinico_medicina_interna475.txt
# 		 Working on text:  caso_clinico_psiquiatria477.txt
# 		 Working on text:  caso_clinico_neurologia83.txt
# 		 Working on text:  caso_clinico_psiquiatria195.txt
# 		 Working on text:  caso_clinico_psiquiatria516.txt
# 		 Working on text:  caso_clinico_psiquiatria474.txt
# 		 Working on text:  caso_clinico_medicina_interna622.txt
# 		 Working on text:  caso_clinico_psiquiatria428.txt
# 		 Working on text:  casos_clinicos_profesiones186.txt
# 		 Working on text:  casos_clinicos_profesiones114.txt
# 		 Working on text:  casos_clinicos_profesiones191.txt
# 		 Working on text:  caso_clinico_medicina_interna48.txt
# 		 Working on text:  caso_clinico_psiquiatria52.txt
# 		 Working on text:  casos_clinicos_profesiones220.txt
# 		 Working on text:  casos_clinicos_profesiones76.txt
# 		 Working on text:  caso_clinico_psiquiatria398.txt
# 		 Working on text:  caso_clinico_endocrinologia149.txt
# 		 Working on text:  casos_clinicos_profesiones224.txt
# 		 Working on text:  caso_clinico_psiquiatria154.txt
# 		 Working on text:  casos_clinicos_profesiones228.txt
# 		 Working on text:  caso_clinico_psiquiatria250.txt
# 		 Working on text:  caso_clinico_psiquiatria324.txt
# 		 Working on text:  casos_clinicos_profesiones226.txt
# 		 Working on text:  S0034-98872012001100010-1.txt
# 		 Working on text:  caso_clinico_psiquiatria546.txt
# 		 Working on text:  casos_clinicos_profesiones136.txt
# 		 Working on text:  caso_clinico_psiquiatria140.txt
# 		 Working on text:  casos_clinicos_profesiones176.txt
# 		 Working on text:  S1130-52742017000100001-1.txt
# 		 Working on text:  caso_clinico_neurologia286.txt
# 		 Working on text:  caso_clinico_medicina_interna1274.txt
# 		 Working on text:  caso_clinico_psiquiatria232.txt
# 		 Working on text:  cc_onco1193.txt
# 		 Working on text:  casos_clinicos_profesiones22.txt
# 		 Working on text:  caso_clinico_neurologia350.txt
# 		 Working on text:  casos_clinicos_profesiones203.txt
# 		 Working on text:  caso_clinico_psiquiatria304.txt
# 		 Working on text:  casos_clinicos_profesiones107.txt
# 		 Working on text:  casos_clinicos_profesiones193.txt
# 		 Working on text:  cc_onco1121.txt
# 		 Working on text:  caso_clinico_psiquiatria558.txt
# 		 Working on text:  caso_clinico_psiquiatria522.txt
# 		 Working on text:  caso_clinico_neurologia191.txt
# 		 Working on text:  caso_clinico_radiologia988.txt
# 		 Working on text:  casos_clinicos_profesiones225.txt
# 		 Working on text:  casos_clinicos_infecciosas193.txt
# 		 Working on text:  caso_clinico_psiquiatria509.txt
# 		 Working on text:  casos_clinicos_profesiones218.txt
# 		 Working on text:  casos_clinicos_profesiones105.txt
# 		 Working on text:  caso_clinico_medtropical97.txt
# 		 Working on text:  caso_clinico_medicina_interna1053.txt
# 		 Working on text:  32614251_ES.txt
# 		 Working on text:  casos_clinicos_profesiones208.txt
# 		 Working on text:  caso_clinico_medtropical72.txt
# 		 Working on text:  casos_clinicos_profesiones207.txt
# 		 Working on text:  casos_clinicos_profesiones163.txt
# 		 Working on text:  caso_clinico_medicina_interna1242.txt
# 		 Working on text:  casos_clinicos_profesiones157.txt
# 		 Working on text:  casos_clinicos_profesiones144.txt
# 		 Working on text:  casos_clinicos_profesiones200.txt
# 		 Working on text:  casos_clinicos_profesiones231.txt
# 		 Working on text:  caso_clinico_psiquiatria371.txt
# 		 Working on text:  S1130-01082015000700010-1.txt
# 		 Working on text:  casos_clinicos_infecciosas115.txt
# 		 Working on text:  caso_clinico_psiquiatria561.txt
# 		 Working on text:  cc_onco777.txt
# 		 Working on text:  caso_clinico_psiquiatria541.txt
# 		 Working on text:  casos_clinicos_profesiones104.txt
# 		 Working on text:  S1132-62552015000100005-1.txt
# 		 Working on text:  caso_clinico_dermatologia618.txt
# 		 Working on text:  casos_clinicos_profesiones201.txt
# 		 Working on text:  casos_clinicos_profesiones169.txt
# 		 Working on text:  caso_clinico_psiquiatria159.txt
# 		 Working on text:  casos_clinicos_profesiones162.txt
# 		 Working on text:  caso_clinico_dermatologia447.txt
# 		 Working on text:  casos_clinicos_profesiones121.txt
# 		 Working on text:  cc_reuma60.txt
# 		 Working on text:  caso_clinico_atencion_primaria33.txt
# 		 Working on text:  casos_clinicos_profesiones213.txt
# 		 Working on text:  caso_clinico_psiquiatria136.txt
# 		 Working on text:  caso_clinico_medicina_interna888.txt
# 		 Working on text:  S1134-80462015000200005-1.txt
# 		 Working on text:  casos_clinicos_profesiones202.txt
# 		 Working on text:  caso_clinico_psiquiatria400.txt
# 		 Working on text:  caso_clinico_medicina_interna1482.txt
# 		 Working on text:  casos_clinicos_profesiones229.txt
# 		 Working on text:  caso_clinico_urgencias85.txt
# 		 Working on text:  caso_clinico_psiquiatria175.txt
# 		 Working on text:  casos_clinicos_profesiones160.txt
# 		 Working on text:  caso_clinico_urologia266.txt
# 		 Working on text:  caso_clinico_neurologia61.txt
# 		 Working on text:  caso_clinico_psiquiatria163.txt
# 		 Working on text:  caso_clinico_medtropical28.txt
# 		 Working on text:  casos_clinicos_profesiones142.txt
# 		 Working on text:  casos_clinicos_profesiones15.txt
# 		 Working on text:  caso_clinico_psiquiatria440.txt
# 		 Working on text:  caso_clinico_psiquiatria418.txt
# 		 Working on text:  caso_clinico_psiquiatria412.txt
# 		 Working on text:  cc_onco1486.txt
# 		 Working on text:  caso_clinico_psiquiatria226.txt
# 		 Working on text:  S0376-78922009000100011-1.txt
# 		 Working on text:  cc_onco145.txt
# 		 Working on text:  casos_clinicos_profesiones139.txt
# 		 Working on text:  casos_clinicos_profesiones122.txt
# 		 Working on text:  casos_clinicos_profesiones119.txt
# 		 Working on text:  casos_clinicos_profesiones172.txt
# 		 Working on text:  casos_clinicos_profesiones164.txt
# 		 Working on text:  caso_clinico_psiquiatria5.txt
# 		 Working on text:  caso_clinico_radiologia986.txt
# 		 Working on text:  casos_clinicos_profesiones198.txt
# 		 Working on text:  casos_clinicos_profesiones132.txt
# 		 Working on text:  caso_clinico_dermatologia197.txt
# 		 Working on text:  caso_clinico_atencion_primaria3.txt
# 		 Working on text:  casos_clinicos_profesiones171.txt
# 		 Working on text:  caso_clinico_psiquiatria433.txt
# 		 Working on text:  cc_reuma8.txt
# 		 Working on text:  cc_odontologia32.txt
# 		 Working on text:  casos_clinicos_profesiones32.txt
# 		 Working on text:  casos_clinicos_profesiones150.txt
# 		 Working on text:  caso_clinico_psiquiatria490.txt
# 		 Working on text:  caso_clinico_medicina_interna882.txt
# 		 Working on text:  casos_clinicos_profesiones197.txt
# 		 Working on text:  casos_clinicos_profesiones10.txt
# 		 Working on text:  casos_clinicos_profesiones188.txt
# 		 Working on text:  casos_clinicos_profesiones143.txt
# 		 Working on text:  casos_clinicos_profesiones135.txt
# 		 Working on text:  cc_covid45.txt
# 		 Working on text:  casos_clinicos_profesiones212.txt
# 		 Working on text:  caso_clinico_endocrinologia202.txt
# 		 Working on text:  casos_clinicos_profesiones109.txt
# 		 Working on text:  casos_clinicos_profesiones123.txt
# 		 Working on text:  caso_clinico_psiquiatria204.txt
# 		 Working on text:  casos_clinicos_profesiones110.txt
# 		 Working on text:  caso_clinico_medicina_interna388.txt
# 		 Working on text:  caso_clinico_psiquiatria48.txt
# 		 Working on text:  caso_clinico_medicina_interna1373.txt
# 		 Working on text:  cc_onco828.txt
# 		 Working on text:  caso_clinico_medicina_interna1635.txt
# 		 Working on text:  cc_otorrinolaringologia62.txt
# 		 Working on text:  caso_clinico_alergologia69.txt
# 		 Working on text:  caso_clinico_radiologia956.txt
# 		 Working on text:  caso_clinico_psiquiatria308.txt
# 		 Working on text:  caso_clinico_psiquiatria417.txt
# 		 Working on text:  casos_clinicos_profesiones155.txt
# 		 Working on text:  casos_clinicos_infecciosas112.txt
# 		 Working on text:  casos_clinicos_infecciosas117.txt
# 		 Working on text:  caso_clinico_psiquiatria487.txt
# 		 Working on text:  casos_clinicos_profesiones199.txt
# 		 Working on text:  caso_clinico_psiquiatria376.txt
# 		 Working on text:  casos_clinicos_profesiones67.txt
# 		 Working on text:  caso_clinico_psiquiatria39.txt
# 		 Working on text:  casos_clinicos_profesiones219.txt
# 		 Working on text:  casos_clinicos_profesiones36.txt
# 		 Working on text:  casos_clinicos_profesiones161.txt
# 		 Working on text:  casos_clinicos_profesiones156.txt
# 		 Working on text:  cc_onco782.txt
# 		 Working on text:  caso_clinico_psiquiatria94.txt
# 		 Working on text:  casos_clinicos_profesiones111.txt
# 		 Working on text:  caso_clinico_psiquiatria212.txt
# 		 Working on text:  caso_clinico_atencion_primaria175.txt
# 		 Working on text:  caso_clinico_psiquiatria213.txt
# 		 Working on text:  caso_clinico_psiquiatria453.txt
# 		 Working on text:  cc_reuma58.txt
# 		 Working on text:  casos_clinicos_profesiones206.txt
# 		 Working on text:  casos_clinicos_profesiones190.txt
# 		 Working on text:  casos_clinicos_profesiones108.txt
# 		 Working on text:  casos_clinicos_profesiones221.txt
# 		 Working on text:  cc_onco1872.txt
# 		 Working on text:  caso_clinico_psiquiatria167.txt
# 		 Working on text:  casos_clinicos_profesiones153.txt
# 		 Working on text:  casos_clinicos_profesiones77.txt
# 		 Working on text:  casos_clinicos_profesiones21.txt
# 		 Working on text:  caso_clinico_atencion_primaria146.txt
# 		 Working on text:  casos_clinicos_profesiones24.txt
# 		 Working on text:  caso_clinico_psiquiatria78.txt
# 		 Working on text:  casos_clinicos_infecciosas113.txt
# 		 Working on text:  casos_clinicos_profesiones126.txt
# 		 Working on text:  casos_clinicos_profesiones118.txt
# 		 Working on text:  casos_clinicos_profesiones38.txt
# 		 Working on text:  casos_clinicos_profesiones131.txt
# 		 Working on text:  casos_clinicos_profesiones233.txt
# 		 Working on text:  casos_clinicos_profesiones179.txt
# 		 Working on text:  caso_clinico_dermatologia137.txt
# 		 Working on text:  caso_clinico_psiquiatria260.txt
# 		 Working on text:  casos_clinicos_profesiones215.txt
# 		 Working on text:  caso_clinico_psiquiatria301.txt
# 		 Working on text:  casos_clinicos_profesiones227.txt
# 		 Working on text:  casos_clinicos_profesiones154.txt
# 		 Working on text:  cc_onco1559.txt
# 		 Working on text:  caso_clinico_atencion_primaria104.txt
# 		 Working on text:  caso_clinico_medicina_interna1270.txt
# 		 Working on text:  cc_onco718.txt
# 		 Working on text:  cc_reuma56.txt
# 		 Working on text:  caso_clinico_psiquiatria347.txt
# 		 Working on text:  casos_clinicos_profesiones180.txt
# 		 Working on text:  caso_clinico_psiquiatria64.txt
# 		 Working on text:  casos_clinicos_profesiones95.txt
# 		 Working on text:  caso_clinico_oftalmologia157.txt
# 		 Working on text:  caso_clinico_psiquiatria32.txt
# 		 Working on text:  casos_clinicos_profesiones102.txt
# 		 Working on text:  casos_clinicos_profesiones211.txt
# 		 Working on text:  cc_reuma55.txt
# 		 Working on text:  casos_clinicos_profesiones12.txt
# 		 Working on text:  casos_clinicos_profesiones214.txt
# 		 Working on text:  casos_clinicos_profesiones103.txt
# 		 Working on text:  casos_clinicos_profesiones130.txt
# 		 Working on text:  casos_clinicos_profesiones133.txt
# 		 Working on text:  casos_clinicos_profesiones11.txt
# 		 Working on text:  caso_clinico_atencion_primaria29.txt
# 		 Working on text:  casos_clinicos_profesiones124.txt
# 		 Working on text:  caso_clinico_psiquiatria63.txt
# 		 Working on text:  caso_clinico_medicina_interna1352.txt
# 		 Working on text:  casos_clinicos_profesiones149.txt
# 		 Working on text:  casos_clinicos_profesiones216.txt
# 		 Working on text:  casos_clinicos_profesiones30.txt
# 		 Working on text:  casos_clinicos_profesiones204.txt
# 		 Working on text:  cc_onco923.txt
# 		 Working on text:  casos_clinicos_profesiones184.txt
# 		 Working on text:  casos_clinicos_profesiones148.txt
# 		 Working on text:  caso_clinico_urologia270.txt
# 		 Working on text:  caso_clinico_psiquiatria530.txt
# 		 Working on text:  casos_clinicos_profesiones175.txt
# 		 Working on text:  cc_onco521.txt
# 		 Working on text:  caso_clinico_psiquiatria382.txt
# 		 Working on text:  caso_clinico_psiquiatria58.txt
# 		 Working on text:  casos_clinicos_profesiones146.txt
# 		 Working on text:  caso_clinico_psiquiatria86.txt
# 		 Working on text:  caso_clinico_psiquiatria14.txt
# 		 Working on text:  casos_clinicos_profesiones165.txt
# 		 Working on text:  caso_clinico_psiquiatria493.txt
# 		 Working on text:  caso_clinico_psiquiatria390.txt
# 		 Working on text:  casos_clinicos_profesiones205.txt
# 		 Working on text:  casos_clinicos_profesiones230.txt
# 		 Working on text:  casos_clinicos_profesiones194.txt
# 		 Working on text:  casos_clinicos_profesiones170.txt
# 		 Working on text:  casos_clinicos_profesiones174.txt
# 		 Working on text:  caso_clinico_psiquiatria267.txt
# 		 Working on text:  casos_clinicos_profesiones140.txt
# 		 Working on text:  casos_clinicos_profesiones209.txt
# 		 Working on text:  casos_clinicos_profesiones152.txt
# 		 Working on text:  S0004-06142009000100010-2.txt
# 		 Working on text:  cc_onco825.txt
# 		 Working on text:  casos_clinicos_profesiones223.txt
# 		 Working on text:  caso_clinico_medicina_interna22.txt
# 		 Working on text:  cc_otorrinolaringologia76.txt
# 		 Working on text:  casos_clinicos_profesiones27.txt
# 		 Working on text:  caso_clinico_urologia53.txt
# 		 Working on text:  32423911_ES.txt
# 		 Working on text:  cc_onco981.txt
# 		 Working on text:  caso_clinico_medicina_interna64.txt
# 		 Working on text:  casos_clinicos_profesiones151.txt
# 		 Working on text:  casos_clinicos_profesiones65.txt
# 		 Working on text:  casos_clinicos_profesiones182.txt
# 		 Working on text:  caso_clinico_psiquiatria401.txt
# 		 Working on text:  casos_clinicos_profesiones120.txt
# 		 Working on text:  caso_clinico_psiquiatria359.txt
# 		 Working on text:  caso_clinico_psiquiatria483.txt
# 		 Working on text:  casos_clinicos_profesiones185.txt
# 		 Working on text:  casos_clinicos_profesiones127.txt
# 		 Working on text:  caso_clinico_psiquiatria305.txt
# 		 Working on text:  casos_clinicos_profesiones177.txt
# 		 Working on text:  casos_clinicos_infecciosas82.txt
# 		 Working on text:  caso_clinico_psiquiatria246.txt
# 		 Working on text:  caso_clinico_dermatologia242.txt
# 		 Working on text:  casos_clinicos_infecciosas53.txt
# 		 Working on text:  32605766_ES.txt
# 		 Working on text:  caso_clinico_medicina_interna1486.txt
# 		 Working on text:  casos_clinicos_profesiones217.txt
# 		 Working on text:  caso_clinico_psiquiatria462.txt
# 		 Working on text:  caso_clinico_psiquiatria66.txt
# 		 Working on text:  caso_clinico_neurologia101.txt
# 		 Working on text:  cc_odontologia15.txt
# 		 Working on text:  caso_clinico_psiquiatria220.txt
# 		 Working on text:  caso_clinico_psiquiatria216.txt
# 		 Working on text:  casos_clinicos_profesiones57.txt
# 		 Working on text:  casos_clinicos_profesiones137.txt
# 		 Working on text:  casos_clinicos_profesiones183.txt
# 		 Working on text:  casos_clinicos_profesiones189.txt
# 		 Working on text:  casos_clinicos_profesiones128.txt

# %%
# !git clone https://github.com/TeMU-BSC/meddoprof-evaluation-library.git

# %%
# !python ./meddoprof-evaluation-library/src/main.py -g ../input/meddoprofner-task/experiments/experiments/test -p ./out -c ./meddoprof-evaluation-library/meddoprof_valid_codes.tsv -s ner

# %%
# !zip -r ./flair_bert_meddoprof_submission.zip ./out
# Out:
#   adding: out/ (stored 0%)
#   adding: out/casos_clinicos_profesiones123.ann (stored 0%)
#   adding: out/S0034-98872006000200011-1.ann (deflated 10%)
#   adding: out/S0034-98872012001100010-1.ann (deflated 9%)
#   adding: out/casos_clinicos_profesiones188.ann (deflated 37%)
#   adding: out/caso_clinico_dermatologia469.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones124.ann (stored 0%)
#   adding: out/cc_reuma56.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria440.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria474.ann (deflated 14%)
#   adding: out/caso_clinico_urologia270.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones212.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones222.ann (deflated 39%)
#   adding: out/casos_clinicos_profesiones204.ann (deflated 41%)
#   adding: out/casos_clinicos_profesiones138.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones139.ann (deflated 11%)
#   adding: out/caso_clinico_medtropical28.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones216.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria250.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria229.ann (stored 0%)
#   adding: out/cc_onco981.ann (deflated 8%)
#   adding: out/cc_odontologia32.ann (stored 0%)
#   adding: out/caso_clinico_atencion_primaria92.ann (deflated 6%)
#   adding: out/casos_clinicos_profesiones155.ann (deflated 12%)
#   adding: out/casos_clinicos_profesiones112.ann (deflated 25%)
#   adding: out/casos_clinicos_profesiones110.ann (deflated 9%)
#   adding: out/caso_clinico_radiologia988.ann (stored 0%)
#   adding: out/cc_onco1193.ann (deflated 9%)
#   adding: out/caso_clinico_urologia266.ann (deflated 13%)
#   adding: out/casos_clinicos_profesiones175.ann (deflated 30%)
#   adding: out/caso_clinico_psiquiatria58.ann (deflated 1%)
#   adding: out/casos_clinicos_profesiones152.ann (deflated 42%)
#   adding: out/casos_clinicos_profesiones130.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones184.ann (stored 0%)
#   adding: out/cc_onco611.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones103.ann (deflated 1%)
#   adding: out/caso_clinico_psiquiatria477.ann (deflated 36%)
#   adding: out/caso_clinico_medicina_interna888.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones15.ann (deflated 1%)
#   adding: out/caso_clinico_medicina_interna1053.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones161.ann (deflated 21%)
#   adding: out/casos_clinicos_infecciosas115.ann (stored 0%)
#   adding: out/casos_clinicos_infecciosas117.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria66.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones163.ann (deflated 35%)
#   adding: out/caso_clinico_psiquiatria412.ann (deflated 9%)
#   adding: out/caso_clinico_endocrinologia149.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria347.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria509.ann (deflated 21%)
#   adding: out/casos_clinicos_profesiones231.ann (stored 0%)
#   adding: out/caso_clinico_medicina_interna644.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria308.ann (deflated 33%)
#   adding: out/casos_clinicos_profesiones194.ann (stored 0%)
#   adding: out/caso_clinico_medicina_interna1700.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones136.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria163.ann (deflated 40%)
#   adding: out/casos_clinicos_profesiones198.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones95.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones196.ann (deflated 14%)
#   adding: out/casos_clinicos_profesiones193.ann (deflated 37%)
#   adding: out/casos_clinicos_profesiones197.ann (deflated 33%)
#   adding: out/cc_otorrinolaringologia76.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria305.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones153.ann (stored 0%)
#   adding: out/caso_clinico_medicina_interna1482.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones151.ann (deflated 47%)
#   adding: out/caso_clinico_psiquiatria78.ann (deflated 49%)
#   adding: out/cc_onco1033.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria366.ann (deflated 8%)
#   adding: out/casos_clinicos_profesiones183.ann (deflated 35%)
#   adding: out/casos_clinicos_profesiones114.ann (stored 0%)
#   adding: out/S0376-78922009000100011-1.ann (deflated 18%)
#   adding: out/casos_clinicos_profesiones219.ann (stored 0%)
#   adding: out/S0004-06142009000100010-2.ann (deflated 1%)
#   adding: out/casos_clinicos_profesiones217.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones127.ann (deflated 41%)
#   adding: out/casos_clinicos_profesiones119.ann (deflated 13%)
#   adding: out/casos_clinicos_profesiones156.ann (deflated 26%)
#   adding: out/casos_clinicos_profesiones226.ann (deflated 1%)
#   adding: out/caso_clinico_medicina_interna240.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones203.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria417.ann (deflated 46%)
#   adding: out/casos_clinicos_profesiones129.ann (deflated 11%)
#   adding: out/casos_clinicos_profesiones115.ann (deflated 11%)
#   adding: out/casos_clinicos_profesiones65.ann (stored 0%)
#   adding: out/caso_clinico_medicina_interna1242.ann (deflated 21%)
#   adding: out/caso_clinico_medicina_interna882.ann (stored 0%)
#   adding: out/caso_clinico_dermatologia197.ann (stored 0%)
#   adding: out/caso_clinico_endocrinologia202.ann (stored 0%)
#   adding: out/caso_clinico_neurologia350.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones230.ann (stored 0%)
#   adding: out/caso_clinico_medicina_interna1635.ann (deflated 21%)
#   adding: out/caso_clinico_medtropical97.ann (deflated 45%)
#   adding: out/cc_onco782.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones207.ann (deflated 45%)
#   adding: out/caso_clinico_neurologia83.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria546.ann (deflated 18%)
#   adding: out/caso_clinico_medicina_interna1352.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria371.ann (deflated 45%)
#   adding: out/caso_clinico_psiquiatria32.ann (deflated 49%)
#   adding: out/casos_clinicos_profesiones191.ann (stored 0%)
#   adding: out/caso_clinico_medicina_interna475.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones10.ann (deflated 17%)
#   adding: out/casos_clinicos_profesiones137.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones147.ann (deflated 47%)
#   adding: out/casos_clinicos_profesiones106.ann (stored 0%)
#   adding: out/cc_covid45.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones148.ann (deflated 10%)
#   adding: out/caso_clinico_dermatologia456.ann (deflated 8%)
#   adding: out/caso_clinico_neurologia101.ann (stored 0%)
#   adding: out/cc_onco627.ann (deflated 15%)
#   adding: out/caso_clinico_psiquiatria260.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones67.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones201.ann (deflated 12%)
#   adding: out/caso_clinico_dermatologia160.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones36.ann (deflated 42%)
#   adding: out/caso_clinico_medicina_interna388.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones178.ann (deflated 14%)
#   adding: out/casos_clinicos_profesiones158.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones30.ann (deflated 29%)
#   adding: out/caso_clinico_medicina_interna407.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria39.ann (deflated 35%)
#   adding: out/casos_clinicos_profesiones146.ann (deflated 28%)
#   adding: out/casos_clinicos_profesiones141.ann (deflated 40%)
#   adding: out/32614251_ES.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones225.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones76.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria382.ann (deflated 53%)
#   adding: out/caso_clinico_medicina_interna1373.ann (stored 0%)
#   adding: out/caso_clinico_atencion_primaria33.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones169.ann (deflated 7%)
#   adding: out/caso_clinico_dermatologia390.ann (stored 0%)
#   adding: out/32423911_ES.ann (deflated 28%)
#   adding: out/casos_clinicos_profesiones224.ann (deflated 8%)
#   adding: out/caso_clinico_medicina_interna1274.ann (stored 0%)
#   adding: out/casos_clinicos_infecciosas112.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones157.ann (deflated 14%)
#   adding: out/casos_clinicos_profesiones143.ann (deflated 6%)
#   adding: out/caso_clinico_urologia53.ann (deflated 8%)
#   adding: out/caso_clinico_atencion_primaria3.ann (deflated 32%)
#   adding: out/casos_clinicos_profesiones170.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones107.ann (deflated 15%)
#   adding: out/caso_clinico_atencion_primaria146.ann (deflated 42%)
#   adding: out/casos_clinicos_profesiones218.ann (deflated 23%)
#   adding: out/casos_clinicos_profesiones159.ann (deflated 51%)
#   adding: out/cc_odontologia15.ann (stored 0%)
#   adding: out/caso_clinico_neurologia61.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones189.ann (stored 0%)
#   adding: out/casos_clinicos_infecciosas113.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria541.ann (deflated 40%)
#   adding: out/casos_clinicos_profesiones182.ann (deflated 31%)
#   adding: out/caso_clinico_psiquiatria398.ann (deflated 23%)
#   adding: out/casos_clinicos_profesiones164.ann (deflated 20%)
#   adding: out/casos_clinicos_profesiones27.ann (deflated 40%)
#   adding: out/cc_reuma8.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria175.ann (deflated 29%)
#   adding: out/casos_clinicos_profesiones21.ann (deflated 38%)
#   adding: out/casos_clinicos_profesiones113.ann (deflated 16%)
#   adding: out/cc_reuma14.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones180.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria304.ann (deflated 54%)
#   adding: out/caso_clinico_psiquiatria220.ann (deflated 36%)
#   adding: out/caso_clinico_psiquiatria213.ann (stored 0%)
#   adding: out/caso_clinico_dermatologia123.ann (deflated 9%)
#   adding: out/casos_clinicos_profesiones172.ann (deflated 18%)
#   adding: out/casos_clinicos_profesiones227.ann (deflated 42%)
#   adding: out/caso_clinico_oftalmologia188.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones57.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria530.ann (deflated 39%)
#   adding: out/casos_clinicos_profesiones186.ann (deflated 15%)
#   adding: out/caso_clinico_psiquiatria390.ann (deflated 52%)
#   adding: out/casos_clinicos_profesiones126.ann (deflated 36%)
#   adding: out/caso_clinico_medicina_interna22.ann (deflated 25%)
#   adding: out/caso_clinico_psiquiatria63.ann (deflated 19%)
#   adding: out/casos_clinicos_profesiones210.ann (deflated 30%)
#   adding: out/caso_clinico_psiquiatria64.ann (deflated 38%)
#   adding: out/casos_clinicos_profesiones215.ann (stored 0%)
#   adding: out/casos_clinicos_infecciosas193.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria5.ann (deflated 8%)
#   adding: out/casos_clinicos_profesiones179.ann (deflated 12%)
#   adding: out/casos_clinicos_profesiones167.ann (deflated 27%)
#   adding: out/caso_clinico_dermatologia242.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria69.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria438.ann (deflated 40%)
#   adding: out/caso_clinico_medicina_interna1270.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones177.ann (deflated 34%)
#   adding: out/caso_clinico_dermatologia618.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones132.ann (stored 0%)
#   adding: out/caso_clinico_atencion_primaria104.ann (deflated 19%)
#   adding: out/caso_clinico_psiquiatria14.ann (deflated 51%)
#   adding: out/caso_clinico_radiologia986.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria52.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones38.ann (deflated 45%)
#   adding: out/casos_clinicos_profesiones223.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones228.ann (deflated 47%)
#   adding: out/casos_clinicos_profesiones133.ann (deflated 26%)
#   adding: out/casos_clinicos_profesiones181.ann (deflated 3%)
#   adding: out/caso_clinico_medicina_interna64.ann (stored 0%)
#   adding: out/cc_onco1574.ann (deflated 7%)
#   adding: out/caso_clinico_psiquiatria376.ann (stored 0%)
#   adding: out/caso_clinico_urologia58.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones202.ann (deflated 3%)
#   adding: out/cc_onco521.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones145.ann (deflated 35%)
#   adding: out/casos_clinicos_profesiones185.ann (deflated 11%)
#   adding: out/caso_clinico_medicina_interna622.ann (deflated 10%)
#   adding: out/caso_clinico_oftalmologia157.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria324.ann (stored 0%)
#   adding: out/cc_onco1486.ann (stored 0%)
#   adding: out/caso_clinico_dermatologia137.ann (deflated 8%)
#   adding: out/cc_onco825.ann (deflated 6%)
#   adding: out/caso_clinico_dermatologia447.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones205.ann (deflated 34%)
#   adding: out/caso_clinico_psiquiatria522.ann (stored 0%)
#   adding: out/32605766_ES.ann (deflated 58%)
#   adding: out/casos_clinicos_profesiones187.ann (deflated 22%)
#   adding: out/casos_clinicos_profesiones149.ann (deflated 38%)
#   adding: out/caso_clinico_psiquiatria359.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria433.ann (deflated 37%)
#   adding: out/caso_clinico_neurologia347.ann (stored 0%)
#   adding: out/caso_clinico_endocrinologia47.ann (stored 0%)
#   adding: out/caso_clinico_atencion_primaria29.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones213.ann (deflated 10%)
#   adding: out/casos_clinicos_profesiones195.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones199.ann (deflated 41%)
#   adding: out/caso_clinico_psiquiatria483.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones174.ann (deflated 46%)
#   adding: out/caso_clinico_neurologia191.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria216.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria428.ann (deflated 25%)
#   adding: out/caso_clinico_psiquiatria360.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones105.ann (stored 0%)
#   adding: out/caso_clinico_radiologia920.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones200.ann (deflated 37%)
#   adding: out/caso_clinico_psiquiatria400.ann (deflated 44%)
#   adding: out/casos_clinicos_profesiones206.ann (deflated 31%)
#   adding: out/caso_clinico_psiquiatria136.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria267.ann (stored 0%)
#   adding: out/casos_clinicos_infecciosas82.ann (stored 0%)
#   adding: out/cc_onco1559.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones108.ann (deflated 46%)
#   adding: out/casos_clinicos_profesiones160.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones104.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones22.ann (deflated 33%)
#   adding: out/caso_clinico_psiquiatria140.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones165.ann (deflated 39%)
#   adding: out/caso_clinico_psiquiatria418.ann (deflated 18%)
#   adding: out/caso_clinico_psiquiatria226.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones122.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones211.ann (deflated 36%)
#   adding: out/casos_clinicos_profesiones109.ann (deflated 22%)
#   adding: out/casos_clinicos_profesiones134.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones140.ann (deflated 15%)
#   adding: out/caso_clinico_psiquiatria212.ann (deflated 19%)
#   adding: out/caso_clinico_psiquiatria487.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones71.ann (stored 0%)
#   adding: out/cc_onco1872.ann (stored 0%)
#   adding: out/caso_clinico_medtropical72.ann (stored 0%)
#   adding: out/caso_clinico_neurologia115.ann (stored 0%)
#   adding: out/caso_clinico_alergologia69.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria195.ann (deflated 16%)
#   adding: out/caso_clinico_psiquiatria490.ann (deflated 24%)
#   adding: out/caso_clinico_psiquiatria86.ann (deflated 38%)
#   adding: out/casos_clinicos_profesiones171.ann (deflated 11%)
#   adding: out/caso_clinico_psiquiatria453.ann (deflated 24%)
#   adding: out/casos_clinicos_profesiones7.ann (deflated 27%)
#   adding: out/casos_clinicos_profesiones233.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones221.ann (deflated 32%)
#   adding: out/cc_otorrinolaringologia62.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones214.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones168.ann (stored 0%)
#   adding: out/cc_reuma3.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones11.ann (deflated 19%)
#   adding: out/caso_clinico_neurologia286.ann (deflated 10%)
#   adding: out/casos_clinicos_profesiones144.ann (deflated 2%)
#   adding: out/S1134-80462015000200005-1.ann (deflated 17%)
#   adding: out/caso_clinico_psiquiatria167.ann (deflated 34%)
#   adding: out/caso_clinico_psiquiatria516.ann (stored 0%)
#   adding: out/cc_reuma60.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones77.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones117.ann (deflated 22%)
#   adding: out/caso_clinico_psiquiatria518.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria301.ann (deflated 34%)
#   adding: out/casos_clinicos_profesiones135.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones190.ann (stored 0%)
#   adding: out/caso_clinico_medicina_interna996.ann (deflated 17%)
#   adding: out/casos_clinicos_profesiones229.ann (deflated 8%)
#   adding: out/caso_clinico_psiquiatria471.ann (deflated 39%)
#   adding: out/casos_clinicos_profesiones128.ann (deflated 7%)
#   adding: out/cc_onco884.ann (stored 0%)
#   adding: out/caso_clinico_neurologia195.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria159.ann (deflated 41%)
#   adding: out/caso_clinico_atencion_primaria175.ann (deflated 27%)
#   adding: out/caso_clinico_psiquiatria561.ann (deflated 16%)
#   adding: out/casos_clinicos_profesiones32.ann (deflated 15%)
#   adding: out/caso_clinico_psiquiatria154.ann (deflated 35%)
#   adding: out/casos_clinicos_profesiones120.ann (deflated 37%)
#   adding: out/casos_clinicos_profesiones166.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones102.ann (deflated 14%)
#   adding: out/casos_clinicos_profesiones232.ann (deflated 29%)
#   adding: out/casos_clinicos_profesiones116.ann (deflated 42%)
#   adding: out/casos_clinicos_profesiones162.ann (deflated 8%)
#   adding: out/caso_clinico_psiquiatria22.ann (deflated 1%)
#   adding: out/casos_clinicos_profesiones208.ann (deflated 48%)
#   adding: out/caso_clinico_medicina_interna48.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones173.ann (deflated 37%)
#   adding: out/casos_clinicos_profesiones125.ann (deflated 32%)
#   adding: out/caso_clinico_urgencias85.ann (deflated 11%)
#   adding: out/caso_clinico_psiquiatria246.ann (stored 0%)
#   adding: out/caso_clinico_medicina_interna1486.ann (stored 0%)
#   adding: out/cc_onco777.ann (deflated 10%)
#   adding: out/cc_onco1121.ann (stored 0%)
#   adding: out/cc_onco145.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones131.ann (stored 0%)
#   adding: out/casos_clinicos_infecciosas53.ann (deflated 45%)
#   adding: out/casos_clinicos_profesiones176.ann (deflated 60%)
#   adding: out/casos_clinicos_profesiones154.ann (deflated 4%)
#   adding: out/casos_clinicos_profesiones12.ann (deflated 27%)
#   adding: out/caso_clinico_psiquiatria401.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria204.ann (deflated 6%)
#   adding: out/S1132-62552015000100005-1.ann (deflated 52%)
#   adding: out/caso_clinico_psiquiatria558.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria48.ann (deflated 35%)
#   adding: out/caso_clinico_psiquiatria232.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria94.ann (deflated 34%)
#   adding: out/cc_onco923.ann (stored 0%)
#   adding: out/cc_reuma35.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones142.ann (deflated 54%)
#   adding: out/casos_clinicos_profesiones192.ann (deflated 8%)
#   adding: out/cc_onco718.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones111.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones209.ann (deflated 37%)
#   adding: out/cc_onco828.ann (deflated 25%)
#   adding: out/caso_clinico_radiologia956.ann (deflated 21%)
#   adding: out/casos_clinicos_profesiones24.ann (deflated 43%)
#   adding: out/casos_clinicos_profesiones118.ann (deflated 15%)
#   adding: out/cc_reuma55.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones121.ann (stored 0%)
#   adding: out/caso_clinico_psiquiatria462.ann (stored 0%)
#   adding: out/casos_clinicos_profesiones220.ann (deflated 42%)
#   adding: out/S1130-01082015000700010-1.ann (deflated 13%)
#   adding: out/cc_reuma58.ann (deflated 19%)
#   adding: out/S1130-52742017000100001-1.ann (deflated 31%)
#   adding: out/caso_clinico_psiquiatria493.ann (deflated 16%)
#   adding: out/casos_clinicos_profesiones150.ann (deflated 20%)
